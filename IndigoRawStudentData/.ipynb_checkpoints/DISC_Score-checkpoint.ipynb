# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pyodbc

server = 'hypv8669.hostedbyappliedi.net'
database = 'CCPP'
username = 'ColaberryDB'
password = 'Iam4Colaberry!'

cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

SQL_Query = pd.read_sql_query("""SELECT b.UserID,a.*
                        FROM [dbo].[ADF_Indigo_DISC_Student] a
                        LEFT JOIN dnnuser.users b
                        ON a.[In-Email] = b.Email
                        WHERE [In-Email] IS NOT NULL
                        AND b.UserID IS NOT NULL""",cnxn
                       )

df = pd.DataFrame(SQL_Query)

# %%
print(df.shape)
# Out:
# (791, 167)

# %%
pd.set_option('display.max_columns', None)

# %%
len(df.columns)
# Out:
# 167

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 791 entries, 0 to 790
# Columns: 167 entries, UserID to D-LocationCode
# dtypes: datetime64[ns](1), float64(54), int64(1), object(111)
# memory usage: 1.0+ MB
# None

# %%
df.head()
# Out:
#    UserID       In-LinkName In-FirstName In-LastName In-Gender  \
# 0   32972  Colaberry-I-2020         Assa      Konare         F
# 1   33316  Colaberry-I-2020     Herberth       Lemus         M
# 2   33568  Colaberry-I-2020   Betelihiem       Haile         F
# 3   33683  Colaberry-I-2020        Abebe       Alemu         M
# 4   35076  Colaberry-I-2020       Antony     Karanja         M
#
#    B-DominanceAdapted  B-InfluencingAdapted  B-SteadinessAdapted  \
# 0                46.0                  68.0                 68.0
# 1                92.0                  35.0                 34.0
# 2                58.0                  18.0                 64.0
# 3                34.0                  55.0                 68.0
# 4                 4.0                  12.0                 86.0
#
#    B-ComplianceAdapted  B-DominanceNatural  B-InfluencingNatural  \
# 0                 28.0                38.0                  82.0
# 1                 48.0                89.0                  48.0
# 2                 68.0                48.0                  28.0
# 3                 64.0                18.0                  64.0
# 4                 93.0                 6.0                  32.0
#
#    B-SteadinessNatural  B-ComplianceNatural  M-Theoretical  M-Utilitarian  \
# 0                 64.0                 32.0           65.0           55.0
# 1                 28.0                 42.0           50.0           39.0
# 2                 70.0                 64.0           52.0           29.0
# 3                 80.0                 58.0           70.0           34.0
# 4                 93.0                 93.0           57.0           24.0
#
#    M-Aesthetic  M-Social  M-Individualistic  M-Traditional  \
# 0         31.0      34.0               37.0           30.0
# 1         29.0      45.0               41.0           48.0
# 2         37.0      48.0               52.0           34.0
# 3         34.0      42.0               35.0           37.0
# 4         45.0      58.0               26.0           42.0
#
#   S23-AnalyticalProblemSolving S23-ConflictManagement S23-ContinuousLearning  \
# 0                         None                   None                   None
# 1                         None                   None                   None
# 2                         None                   None                   None
# 3                         None                   None                   None
# 4                         None                   None                   None
#
#   S23-CreativityInnovation S23-PeopleAdvocacy S23-DecisionMaking  \
# 0                     None               None               None
# 1                     None               None               None
# 2                     None               None               None
# 3                     None               None               None
# 4                     None               None               None
#
#   S23-DiplomacyTact S23-Empathy S23-MentoringCoaching  S23-Flexibility  \
# 0              None        None                  None              8.5
# 1              None        None                  None              7.5
# 2              None        None                  None              8.7
# 3              None        None                  None              6.6
# 4              None        None                  None              7.7
#
#    S23-FuturisticThinking  S23-GoalOrientation  S23-InterpersonalSkills  \
# 0                     3.0                  5.3                      1.0
# 1                     0.3                  5.3                      6.3
# 2                     3.3                  9.3                      5.7
# 3                     1.7                  6.0                     10.0
# 4                     1.3                  2.7                      0.3
#
#    S23-Leadership S23-Management  S23-Negotiation  S23-PersonalResponsibility  \
# 0             9.3           None              2.0                         7.3
# 1             6.0           None              4.0                         7.1
# 2             6.0           None              0.0                         7.1
# 3             0.0           None              7.3                         8.5
# 4             2.7           None              1.3                         4.9
#
#    S23-Persuasion  S23-PlanningOrganizing  S23-Presenting  \
# 0             5.0                     5.0             5.7
# 1             1.3                     4.3             3.3
# 2             7.3                     9.0             4.7
# 3             5.0                     7.3             9.3
# 4             4.0                     6.3             4.3
#
#   S23-TimePriorityManagement  S23-Teamwork  S23-WrittenCommunication  \
# 0                       None           5.3                       5.7
# 1                       None           4.3                       6.3
# 2                       None           3.7                       7.7
# 3                       None          10.0                      10.0
# 4                       None           7.7                       8.3
#
#    H-UnderstandingOthers  H-PracticalThinking  H-SystemsJudgment  \
# 0                    9.0                  8.8                8.6
# 1                    9.4                  6.8                7.8
# 2                    8.4                  8.6                8.6
# 3                    6.2                  7.6                8.2
# 4                    8.6                  8.0                8.2
#
#    H-SenseOfSelf  H-RoleAwareness  H-SelfDirection  H-UnderstandingOthersBias  \
# 0            7.8              7.4              6.0                       -1.0
# 1            5.2              6.4              7.2                       -1.0
# 2            8.0              5.2              7.6                        0.0
# 3            8.2              9.6              7.8                       -1.0
# 4            2.4              0.8              5.6                       -1.0
#
#   H-PracticalThinkingBias H-SystemsJudgmentBias H-SenseOfSelfBias  \
# 0                    None                  None              None
# 1                    None                  None              None
# 2                    None                  None              None
# 3                    None                  None              None
# 4                    None                  None              None
#
#   H-RoleAwarenessBias H-SelfDirectionBias  BX-WheelPosition1  \
# 0                None                None                4.0
# 1                None                None                1.0
# 2                None                None               37.0
# 3                None                None               36.0
# 4                None                None               21.0
#
#    BX-WheelPosition2  BX-Urgency  BX-Interaction  BX-OrganizedWorkplace  \
# 0               15.0         3.4             9.0                    2.5
# 1                1.0         9.2             5.0                    4.2
# 2               20.0         3.6             3.5                    8.5
# 3               34.0         1.8             6.0                    4.5
# 4                6.0         1.0             2.5                    9.0
#
#    BX-Analysis  BX-Competitive  BX-Versatile  BX-PeopleOriented  \
# 0          2.5             4.0           7.0                8.5
# 1          5.5            10.0           6.5                4.5
# 2          8.5             5.0           3.7                4.5
# 3          5.0             2.0           5.0                8.0
# 4          9.0             1.0           2.0                6.5
#
#    BX-FrequentChange  BX-Consistent  BX-CustomerOriented  BX-Persistence  \
# 0                6.0            5.5                  8.7             5.0
# 1                7.0            4.0                  3.7             5.0
# 2                3.8            8.0                  5.8             8.7
# 3                4.2            7.5                  7.8             6.7
# 4                1.5            9.5                  5.5             8.7
#
#    BX-FollowingPolicy HX-AccountabilityForOthers HX-AttentionToDetail  \
# 0                 4.8                       None                 None
# 1                 4.8                       None                 None
# 2                 7.5                       None                 None
# 3                 7.0                       None                 None
# 4                 9.5                       None                 None
#
#   HX-AttitudeTowardOthers HX-BalancedDecisionMaking  \
# 0                    None                      None
# 1                    None                      None
# 2                    None                      None
# 3                    None                      None
# 4                    None                      None
#
#    HX-ConceptualThinkingSkill HX-ConcreteOrganization  \
# 0                         8.2                    None
# 1                         6.5                    None
# 2                         8.1                    None
# 3                         7.0                    None
# 4                         7.1                    None
#
#   HX-ConsistencyReliability HX-ConveyingRoleValue HX-CorrectingOthers  \
# 0                      None                  None                None
# 1                      None                  None                None
# 2                      None                  None                None
# 3                      None                  None                None
# 4                      None                  None                None
#
#   HX-DevelopingOthers HX-EmotionalControl HX-EnjoymentOfTheJob  \
# 0                None                None                 None
# 1                None                None                 None
# 2                None                None                 None
# 3                None                None                 None
# 4                None                None                 None
#
#   HX-EvaluatingOthers HX-EvaluatingWhatIsSaid HX-FollowingDirections  \
# 0                None                    None                   None
# 1                None                    None                   None
# 2                None                    None                   None
# 3                None                    None                   None
# 4                None                    None                   None
#
#   HX-FreedomFromPrejudices HX-GainingCommitment HX-HandlingRejection  \
# 0                     None                 None                 None
# 1                     None                 None                 None
# 2                     None                 None                 None
# 3                     None                 None                 None
# 4                     None                 None                 None
#
#   HX-HandlingStress HX-Initiative HX-IntegrativeAbility  \
# 0              None          None                  None
# 1              None          None                  None
# 2              None          None                  None
# 3              None          None                  None
# 4              None          None                  None
#
#   HX-IntuitiveDecisionMaking HX-JobEthic HX-LeadingOthers  \
# 0                       None        None             None
# 1                       None        None             None
# 2                       None        None             None
# 3                       None        None             None
# 4                       None        None             None
#
#   HX-LongRangePlanning HX-MaterialPossessions HX-MeetingStandards  \
# 0                 None                   None                None
# 1                 None                   None                None
# 2                 None                   None                None
# 3                 None                   None                None
# 4                 None                   None                None
#
#   HX-MonitoringOthers HX-PersonalAccountabilitySkill HX-PersonalDrive  \
# 0                None                           None             None
# 1                None                           None             None
# 2                None                           None             None
# 3                None                           None             None
# 4                None                           None             None
#
#   HX-PersonalRelationships  HX-PersuadingOthers HX-ProactiveThinking  \
# 0                     None                  5.7                 None
# 1                     None                  3.3                 None
# 2                     None                  4.7                 None
# 3                     None                  9.3                 None
# 4                     None                  4.3                 None
#
#    HX-ProblemSolving HX-ProjectGoalFocus HX-ProjectScheduling  \
# 0                7.9                None                 None
# 1                7.7                None                 None
# 2                8.6                None                 None
# 3                7.1                None                 None
# 4                7.1                None                 None
#
#   HX-QualityOrientations HX-RealisticExpectations  \
# 0                   None                     None
# 1                   None                     None
# 2                   None                     None
# 3                   None                     None
# 4                   None                     None
#
#   HX-RealisticGoalSettingForOthers HX-RealisticPersonalGoalSetting  \
# 0                             None                            None
# 1                             None                            None
# 2                             None                            None
# 3                             None                            None
# 4                             None                            None
#
#   HX-RelatingToOthers  HX-Resiliency HX-RespectForPolicies  \
# 0                None            6.7                  None
# 1                None            6.8                  None
# 2                None            7.2                  None
# 3                None            8.3                  None
# 4                None            4.7                  None
#
#   HX-ResultsOrientation HX-RoleConfidence HX-SelfAssessment HX-SelfConfidence  \
# 0                  None              None              None              None
# 1                  None              None              None              None
# 2                  None              None              None              None
# 3                  None              None              None              None
# 4                  None              None              None              None
#
#   HX-InternalSelfControl HX-SelfImprovement  HX-SelfManagement  \
# 0                   None               None                7.4
# 1                   None               None                7.3
# 2                   None               None                7.1
# 3                   None               None                8.3
# 4                   None               None                4.3
#
#   HX-SelfStartingAbility HX-SenseOfBelonging HX-SenseOfMission  \
# 0                   None                None              None
# 1                   None                None              None
# 2                   None                None              None
# 3                   None                None              None
# 4                   None                None              None
#
#   HX-SenseOfTiming HX-SensitivityToOthers HX-StatusRecognition  \
# 0             None                   None                 None
# 1             None                   None                 None
# 2             None                   None                 None
# 3             None                   None                 None
# 4             None                   None                 None
#
#   HX-SurrenderingControl HX-TheoreticalProblemSolving  \
# 0                   None                         None
# 1                   None                         None
# 2                   None                         None
# 3                   None                         None
# 4                   None                         None
#
#    HX-UnderstandingMotivationalNeeds HX-UsingCommonSense  \
# 0                                9.0                None
# 1                                9.4                None
# 2                                8.4                None
# 3                                6.2                None
# 4                                8.6                None
#
#   HX-ExternalReliability HX-InternalReliability D-YearBorn D-Ethnicity  \
# 0                   None                   None       None        None
# 1                   None                   None       None        None
# 2                   None                   None       None        None
# 3                   None                   None       None        None
# 4                   None                   None       None        None
#
#   DUN-YearBorn DUN-Ethnicity DUN-CollegeAttending DUN-TransferStudent  \
# 0         None          None                 None                None
# 1         None          None                 None                None
# 2         None          None                 None                None
# 3         None          None                 None                None
# 4         None          None                 None                None
#
#   DUN-CollegeYear DUN-AttendPostGrad DUN-GPA DUN-AreaOfStudy  \
# 0            None               None    None            None
# 1            None               None    None            None
# 2            None               None    None            None
# 3            None               None    None            None
# 4            None               None    None            None
#
#   DUN-OneParentAttendedCollege DUN-HavePayingJob DUN-JobsEnjoyed  \
# 0                         None              None            None
# 1                         None              None            None
# 2                         None              None            None
# 3                         None              None            None
# 4                         None              None            None
#
#   DUN-JobsNotRewarding  In-ReportID                In-Email In-Company  \
# 0                 None   12312838.0   1986soumare@gmail.com       None
# 1                 None   12735316.0  1990elylemus@gmail.com       None
# 2                 None   13284354.0      21betzac@gmail.com       None
# 3                 None   13759811.0    a.desalegn@yahoo.com       None
# 4                 None   16378841.0    a.karanja6@gmail.com       None
#
#   In-Position In-ReportDate In-Link In-Password In-ReportViewID  \
# 0        None    2020-03-19    None        None            None
# 1        None    2020-05-02    None        None            None
# 2        None    2020-06-10    None        None            None
# 3        None    2020-07-17    None        None            None
# 4        None    2021-01-25    None        None            None
#
#   In-ReportViewName D-EmploymentStatus D-Occupation D-Experience D-Income  \
# 0              None               None         None         None     None
# 1              None               None         None         None     None
# 2              None               None         None         None     None
# 3              None               None         None         None     None
# 4              None               None         None         None     None
#
#   D-VeteranStatus D-Disabled D-Education D-CollegeMajor D-Country D-State  \
# 0            None       None        None           None      None    None
# 1            None       None        None           None      None    None
# 2            None       None        None           None      None    None
# 3            None       None        None           None      None    None
# 4            None       None        None           None      None    None
#
#   D-ZipOrPostalCode D-HighSchoolLeadershiperRoles D-MajorRelatedJobs  \
# 0              None                          None               None
# 1              None                          None               None
# 2              None                          None               None
# 3              None                          None               None
# 4              None                          None               None
#
#   D-LocationCode
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None

# %%
df.describe()
# Out:
#              UserID  B-DominanceAdapted  B-InfluencingAdapted  \
# count    791.000000          791.000000            791.000000
# mean   33222.034134           37.092288             50.907712
# std     3403.169735           19.022980             19.164322
# min      476.000000            2.000000              4.000000
# 25%    32755.000000           25.000000             38.000000
# 50%    33765.000000           37.000000             52.000000
# 75%    34743.500000           48.000000             63.500000
# max    37004.000000           97.000000             97.000000
#
#        B-SteadinessAdapted  B-ComplianceAdapted  B-DominanceNatural  \
# count           791.000000           791.000000          791.000000
# mean             62.226296            64.328698           39.658660
# std              19.375911            18.412796           19.065106
# min               4.000000             7.000000            5.000000
# 25%              52.000000            55.000000           26.000000
# 50%              64.000000            64.000000           37.000000
# 75%              78.000000            78.000000           53.000000
# max              94.000000            95.000000          100.000000
#
#        B-InfluencingNatural  B-SteadinessNatural  B-ComplianceNatural  \
# count            791.000000           791.000000           791.000000
# mean              52.801517            64.054362            59.088496
# std               19.111659            19.615309            19.832137
# min                6.000000             7.000000             7.000000
# 25%               38.000000            54.000000            45.000000
# 50%               55.000000            66.000000            61.000000
# 75%               66.000000            77.000000            74.000000
# max               96.000000           100.000000            94.000000
#
#        M-Theoretical  M-Utilitarian  M-Aesthetic    M-Social  \
# count     791.000000     791.000000   791.000000  791.000000
# mean       50.286979      43.391909    38.901391   43.016435
# std         9.574085       9.949271     9.364376   11.727215
# min        20.000000      17.000000    19.000000   13.000000
# 25%        44.000000      36.000000    32.000000   35.000000
# 50%        51.000000      43.000000    38.000000   43.000000
# 75%        57.000000      50.000000    45.000000   51.000000
# max        72.000000      71.000000    69.000000   72.000000
#
#        M-Individualistic  M-Traditional  S23-Flexibility  \
# count         791.000000     791.000000       791.000000
# mean           41.544880      34.858407         7.136283
# std            10.479888       9.547227         1.587063
# min            15.000000      13.000000         0.500000
# 25%            34.000000      28.000000         6.700000
# 50%            42.000000      35.000000         7.600000
# 75%            49.000000      41.000000         8.100000
# max            68.000000      69.000000         9.300000
#
#        S23-FuturisticThinking  S23-GoalOrientation  S23-InterpersonalSkills  \
# count              791.000000           791.000000               791.000000
# mean                 2.425664             6.780405                 6.543869
# std                  2.106382             2.314032                 2.898792
# min                  0.000000             0.000000                 0.000000
# 25%                  0.300000             5.300000                 4.700000
# 50%                  2.300000             7.000000                 7.000000
# 75%                  3.850000             8.700000                 9.000000
# max                 10.000000            10.000000                10.000000
#
#        S23-Leadership  S23-Negotiation  S23-PersonalResponsibility  \
# count      791.000000       791.000000                  791.000000
# mean         5.615929         5.096839                    6.556258
# std          2.710855         3.142268                    1.318796
# min          0.000000         0.000000                    0.000000
# 25%          3.700000         2.700000                    6.050000
# 50%          5.700000         5.300000                    6.900000
# 75%          7.700000         7.700000                    7.400000
# max         10.000000        10.000000                    8.700000
#
#        S23-Persuasion  S23-PlanningOrganizing  S23-Presenting  S23-Teamwork  \
# count      791.000000              791.000000      791.000000    791.000000
# mean         4.520228                6.063590        5.067257      6.747408
# std          2.882228                2.374301        2.942263      2.112438
# min          0.000000                0.000000        0.000000      0.000000
# 25%          2.300000                4.700000        2.700000      5.300000
# 50%          4.300000                6.000000        5.000000      6.700000
# 75%          6.700000                8.000000        7.700000      8.300000
# max         10.000000               10.000000       10.000000     10.000000
#
#        S23-WrittenCommunication  H-UnderstandingOthers  H-PracticalThinking  \
# count                791.000000             791.000000           791.000000
# mean                   5.127939               7.589128             7.524399
# std                    2.612665               1.475619             1.660837
# min                    0.000000               0.000000             0.000000
# 25%                    3.300000               7.000000             7.000000
# 50%                    5.000000               8.000000             8.000000
# 75%                    7.000000               8.600000             8.600000
# max                   10.000000              10.000000             9.800000
#
#        H-SystemsJudgment  H-SenseOfSelf  H-RoleAwareness  H-SelfDirection  \
# count         791.000000     791.000000       791.000000       791.000000
# mean            7.382807       6.719595         6.053350         6.538306
# std             1.397179       1.799524         2.019509         1.552698
# min             0.000000       0.000000         0.000000         0.000000
# 25%             7.000000       6.000000         5.400000         5.800000
# 50%             7.600000       7.200000         6.600000         6.800000
# 75%             8.400000       8.000000         7.400000         7.600000
# max             9.600000       9.400000         9.600000         9.400000
#
#        H-UnderstandingOthersBias  BX-WheelPosition1  BX-WheelPosition2  \
# count                 791.000000         791.000000         791.000000
# mean                   -0.562579          28.943110          27.859671
# std                     0.610719          16.181113          15.369764
# min                    -1.000000           0.000000           0.000000
# 25%                    -1.000000          19.000000          17.000000
# 50%                    -1.000000          22.000000          21.000000
# 75%                     0.000000          42.000000          36.000000
# max                     1.000000          60.000000          60.000000
#
#        BX-Urgency  BX-Interaction  BX-OrganizedWorkplace  BX-Analysis  \
# count  791.000000      791.000000             791.000000    791.00000
# mean     3.644627        5.148546               6.111757      6.21732
# std      1.946563        1.998352               2.351805      2.19982
# min      1.000000        1.000000               1.000000      1.00000
# 25%      2.300000        3.750000               4.000000      4.50000
# 50%      3.300000        5.000000               6.500000      6.50000
# 75%      4.500000        6.000000               8.000000      8.00000
# max     10.000000       10.000000              10.000000     10.00000
#
#        BX-Competitive  BX-Versatile  BX-PeopleOriented  BX-FrequentChange  \
# count      791.000000    791.000000         791.000000         791.000000
# mean         4.392794      4.739444           6.359039           4.570038
# std          1.886813      1.630683           1.320497           1.630205
# min          1.000000      1.000000           3.000000           1.000000
# 25%          3.000000      3.700000           5.500000           3.500000
# 50%          4.000000      4.700000           6.500000           4.500000
# 75%          6.000000      5.700000           7.000000           5.800000
# max         10.000000     10.000000          10.000000           9.000000
#
#        BX-Consistent  BX-CustomerOriented  BX-Persistence  BX-FollowingPolicy  \
# count     791.000000           791.000000      791.000000          791.000000
# mean        6.868015             6.448673        6.814918            6.674336
# std         1.698734             1.222767        1.493574            1.543713
# min         1.500000             2.800000        3.000000            2.200000
# 25%         5.800000             5.500000        5.700000            5.500000
# 50%         7.000000             6.500000        6.700000            6.800000
# 75%         8.000000             7.200000        8.000000            7.800000
# max        10.000000            10.000000       10.000000           10.000000
#
#        HX-ConceptualThinkingSkill  HX-PersuadingOthers  HX-ProblemSolving  \
# count                  791.000000           791.000000         791.000000
# mean                     6.838938             5.067257           6.820228
# std                      1.396343             2.942263           1.769315
# min                      0.000000             0.000000           0.000000
# 25%                      6.300000             2.700000           6.200000
# 50%                      7.100000             5.000000           7.200000
# 75%                      7.700000             7.700000           7.900000
# max                      9.600000            10.000000           9.500000
#
#        HX-Resiliency  HX-SelfManagement  HX-UnderstandingMotivationalNeeds  \
# count     791.000000         791.000000                         791.000000
# mean        6.490771           6.549052                           7.589128
# std         1.550509           1.575178                           1.475619
# min         0.600000           0.000000                           0.000000
# 25%         5.800000           6.000000                           7.000000
# 50%         6.900000           6.900000                           8.000000
# 75%         7.500000           7.600000                           8.600000
# max         9.000000           9.000000                          10.000000
#
#         In-ReportID
# count  7.910000e+02
# mean   1.461314e+07
# std    1.936558e+06
# min    1.217095e+07
# 25%    1.285207e+07
# 50%    1.400969e+07
# 75%    1.608362e+07
# max    1.892502e+07

# %%
df.columns
# Out:
# Index(['UserID', 'In-LinkName', 'In-FirstName', 'In-LastName', 'In-Gender',
#        'B-DominanceAdapted', 'B-InfluencingAdapted', 'B-SteadinessAdapted',
#        'B-ComplianceAdapted', 'B-DominanceNatural',
#        ...
#        'D-VeteranStatus', 'D-Disabled', 'D-Education', 'D-CollegeMajor',
#        'D-Country', 'D-State', 'D-ZipOrPostalCode',
#        'D-HighSchoolLeadershiperRoles', 'D-MajorRelatedJobs',
#        'D-LocationCode'],
#       dtype='object', length=167)

# %%
df.drop(['In-LinkName', 'In-FirstName', 'In-LastName','In-Email'],inplace = True,axis=1)

# %%
df.dropna(axis =1,how='all',inplace=True)

# %%
df.describe()
# Out:
#              UserID  B-DominanceAdapted  B-InfluencingAdapted  \
# count    791.000000          791.000000            791.000000
# mean   33222.034134           37.092288             50.907712
# std     3403.169735           19.022980             19.164322
# min      476.000000            2.000000              4.000000
# 25%    32755.000000           25.000000             38.000000
# 50%    33765.000000           37.000000             52.000000
# 75%    34743.500000           48.000000             63.500000
# max    37004.000000           97.000000             97.000000
#
#        B-SteadinessAdapted  B-ComplianceAdapted  B-DominanceNatural  \
# count           791.000000           791.000000          791.000000
# mean             62.226296            64.328698           39.658660
# std              19.375911            18.412796           19.065106
# min               4.000000             7.000000            5.000000
# 25%              52.000000            55.000000           26.000000
# 50%              64.000000            64.000000           37.000000
# 75%              78.000000            78.000000           53.000000
# max              94.000000            95.000000          100.000000
#
#        B-InfluencingNatural  B-SteadinessNatural  B-ComplianceNatural  \
# count            791.000000           791.000000           791.000000
# mean              52.801517            64.054362            59.088496
# std               19.111659            19.615309            19.832137
# min                6.000000             7.000000             7.000000
# 25%               38.000000            54.000000            45.000000
# 50%               55.000000            66.000000            61.000000
# 75%               66.000000            77.000000            74.000000
# max               96.000000           100.000000            94.000000
#
#        M-Theoretical  M-Utilitarian  M-Aesthetic    M-Social  \
# count     791.000000     791.000000   791.000000  791.000000
# mean       50.286979      43.391909    38.901391   43.016435
# std         9.574085       9.949271     9.364376   11.727215
# min        20.000000      17.000000    19.000000   13.000000
# 25%        44.000000      36.000000    32.000000   35.000000
# 50%        51.000000      43.000000    38.000000   43.000000
# 75%        57.000000      50.000000    45.000000   51.000000
# max        72.000000      71.000000    69.000000   72.000000
#
#        M-Individualistic  M-Traditional  S23-Flexibility  \
# count         791.000000     791.000000       791.000000
# mean           41.544880      34.858407         7.136283
# std            10.479888       9.547227         1.587063
# min            15.000000      13.000000         0.500000
# 25%            34.000000      28.000000         6.700000
# 50%            42.000000      35.000000         7.600000
# 75%            49.000000      41.000000         8.100000
# max            68.000000      69.000000         9.300000
#
#        S23-FuturisticThinking  S23-GoalOrientation  S23-InterpersonalSkills  \
# count              791.000000           791.000000               791.000000
# mean                 2.425664             6.780405                 6.543869
# std                  2.106382             2.314032                 2.898792
# min                  0.000000             0.000000                 0.000000
# 25%                  0.300000             5.300000                 4.700000
# 50%                  2.300000             7.000000                 7.000000
# 75%                  3.850000             8.700000                 9.000000
# max                 10.000000            10.000000                10.000000
#
#        S23-Leadership  S23-Negotiation  S23-PersonalResponsibility  \
# count      791.000000       791.000000                  791.000000
# mean         5.615929         5.096839                    6.556258
# std          2.710855         3.142268                    1.318796
# min          0.000000         0.000000                    0.000000
# 25%          3.700000         2.700000                    6.050000
# 50%          5.700000         5.300000                    6.900000
# 75%          7.700000         7.700000                    7.400000
# max         10.000000        10.000000                    8.700000
#
#        S23-Persuasion  S23-PlanningOrganizing  S23-Presenting  S23-Teamwork  \
# count      791.000000              791.000000      791.000000    791.000000
# mean         4.520228                6.063590        5.067257      6.747408
# std          2.882228                2.374301        2.942263      2.112438
# min          0.000000                0.000000        0.000000      0.000000
# 25%          2.300000                4.700000        2.700000      5.300000
# 50%          4.300000                6.000000        5.000000      6.700000
# 75%          6.700000                8.000000        7.700000      8.300000
# max         10.000000               10.000000       10.000000     10.000000
#
#        S23-WrittenCommunication  H-UnderstandingOthers  H-PracticalThinking  \
# count                791.000000             791.000000           791.000000
# mean                   5.127939               7.589128             7.524399
# std                    2.612665               1.475619             1.660837
# min                    0.000000               0.000000             0.000000
# 25%                    3.300000               7.000000             7.000000
# 50%                    5.000000               8.000000             8.000000
# 75%                    7.000000               8.600000             8.600000
# max                   10.000000              10.000000             9.800000
#
#        H-SystemsJudgment  H-SenseOfSelf  H-RoleAwareness  H-SelfDirection  \
# count         791.000000     791.000000       791.000000       791.000000
# mean            7.382807       6.719595         6.053350         6.538306
# std             1.397179       1.799524         2.019509         1.552698
# min             0.000000       0.000000         0.000000         0.000000
# 25%             7.000000       6.000000         5.400000         5.800000
# 50%             7.600000       7.200000         6.600000         6.800000
# 75%             8.400000       8.000000         7.400000         7.600000
# max             9.600000       9.400000         9.600000         9.400000
#
#        H-UnderstandingOthersBias  BX-WheelPosition1  BX-WheelPosition2  \
# count                 791.000000         791.000000         791.000000
# mean                   -0.562579          28.943110          27.859671
# std                     0.610719          16.181113          15.369764
# min                    -1.000000           0.000000           0.000000
# 25%                    -1.000000          19.000000          17.000000
# 50%                    -1.000000          22.000000          21.000000
# 75%                     0.000000          42.000000          36.000000
# max                     1.000000          60.000000          60.000000
#
#        BX-Urgency  BX-Interaction  BX-OrganizedWorkplace  BX-Analysis  \
# count  791.000000      791.000000             791.000000    791.00000
# mean     3.644627        5.148546               6.111757      6.21732
# std      1.946563        1.998352               2.351805      2.19982
# min      1.000000        1.000000               1.000000      1.00000
# 25%      2.300000        3.750000               4.000000      4.50000
# 50%      3.300000        5.000000               6.500000      6.50000
# 75%      4.500000        6.000000               8.000000      8.00000
# max     10.000000       10.000000              10.000000     10.00000
#
#        BX-Competitive  BX-Versatile  BX-PeopleOriented  BX-FrequentChange  \
# count      791.000000    791.000000         791.000000         791.000000
# mean         4.392794      4.739444           6.359039           4.570038
# std          1.886813      1.630683           1.320497           1.630205
# min          1.000000      1.000000           3.000000           1.000000
# 25%          3.000000      3.700000           5.500000           3.500000
# 50%          4.000000      4.700000           6.500000           4.500000
# 75%          6.000000      5.700000           7.000000           5.800000
# max         10.000000     10.000000          10.000000           9.000000
#
#        BX-Consistent  BX-CustomerOriented  BX-Persistence  BX-FollowingPolicy  \
# count     791.000000           791.000000      791.000000          791.000000
# mean        6.868015             6.448673        6.814918            6.674336
# std         1.698734             1.222767        1.493574            1.543713
# min         1.500000             2.800000        3.000000            2.200000
# 25%         5.800000             5.500000        5.700000            5.500000
# 50%         7.000000             6.500000        6.700000            6.800000
# 75%         8.000000             7.200000        8.000000            7.800000
# max        10.000000            10.000000       10.000000           10.000000
#
#        HX-ConceptualThinkingSkill  HX-PersuadingOthers  HX-ProblemSolving  \
# count                  791.000000           791.000000         791.000000
# mean                     6.838938             5.067257           6.820228
# std                      1.396343             2.942263           1.769315
# min                      0.000000             0.000000           0.000000
# 25%                      6.300000             2.700000           6.200000
# 50%                      7.100000             5.000000           7.200000
# 75%                      7.700000             7.700000           7.900000
# max                      9.600000            10.000000           9.500000
#
#        HX-Resiliency  HX-SelfManagement  HX-UnderstandingMotivationalNeeds  \
# count     791.000000         791.000000                         791.000000
# mean        6.490771           6.549052                           7.589128
# std         1.550509           1.575178                           1.475619
# min         0.600000           0.000000                           0.000000
# 25%         5.800000           6.000000                           7.000000
# 50%         6.900000           6.900000                           8.000000
# 75%         7.500000           7.600000                           8.600000
# max         9.000000           9.000000                          10.000000
#
#         In-ReportID
# count  7.910000e+02
# mean   1.461314e+07
# std    1.936558e+06
# min    1.217095e+07
# 25%    1.285207e+07
# 50%    1.400969e+07
# 75%    1.608362e+07
# max    1.892502e+07

# %%
df.columns
# Out:
# Index(['UserID', 'In-Gender', 'B-DominanceAdapted', 'B-InfluencingAdapted',
#        'B-SteadinessAdapted', 'B-ComplianceAdapted', 'B-DominanceNatural',
#        'B-InfluencingNatural', 'B-SteadinessNatural', 'B-ComplianceNatural',
#        'M-Theoretical', 'M-Utilitarian', 'M-Aesthetic', 'M-Social',
#        'M-Individualistic', 'M-Traditional', 'S23-Flexibility',
#        'S23-FuturisticThinking', 'S23-GoalOrientation',
#        'S23-InterpersonalSkills', 'S23-Leadership', 'S23-Negotiation',
#        'S23-PersonalResponsibility', 'S23-Persuasion',
#        'S23-PlanningOrganizing', 'S23-Presenting', 'S23-Teamwork',
#        'S23-WrittenCommunication', 'H-UnderstandingOthers',
#        'H-PracticalThinking', 'H-SystemsJudgment', 'H-SenseOfSelf',
#        'H-RoleAwareness', 'H-SelfDirection', 'H-UnderstandingOthersBias',
#        'BX-WheelPosition1', 'BX-WheelPosition2', 'BX-Urgency',
#        'BX-Interaction', 'BX-OrganizedWorkplace', 'BX-Analysis',
#        'BX-Competitive', 'BX-Versatile', 'BX-PeopleOriented',
#        'BX-FrequentChange', 'BX-Consistent', 'BX-CustomerOriented',
#        'BX-Persistence', 'BX-FollowingPolicy', 'HX-ConceptualThinkingSkill',
#        'HX-PersuadingOthers', 'HX-ProblemSolving', 'HX-Resiliency',
#        'HX-SelfManagement', 'HX-UnderstandingMotivationalNeeds', 'In-ReportID',
#        'In-ReportDate'],
#       dtype='object')

# %%
df['B-InfluencingNatural'].hist() #Close to normal distribution
# Out:
# <AxesSubplot:>

# %%
df['B-InfluencingAdapted'].hist() #Almost the same types of distributions.
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1a6fe1782b2f> in <module>
# ----> 1 sns.pairplot(df)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1987     # Set up the PairGrid
#    1988     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                     hue_order=hue_order, palette=palette, corner=corner,
#    1991                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1181         figsize = len(x_vars) * height * aspect, len(y_vars) * height
#    1182
# -> 1183         fig, axes = plt.subplots(len(y_vars), len(x_vars),
#    1184                                  figsize=figsize,
#    1185                                  sharex="col", sharey="row",
#
# ~\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1438     """
#    1439     fig = figure(**fig_kw)
# -> 1440     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1441                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1442                        gridspec_kw=gridspec_kw)
#
# ~\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     906             gridspec_kw = {}
#     907         gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 908         axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     909                           subplot_kw=subplot_kw)
#     910         return axs
#
# ~\Anaconda3\lib\site-packages\matplotlib\gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     305                 subplot_kw["sharex"] = shared_with[sharex]
#     306                 subplot_kw["sharey"] = shared_with[sharey]
# --> 307                 axarr[row, col] = figure.add_subplot(
#     308                     self[row, col], **subplot_kw)
#     309
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#     779             projection_class, pkw = self._process_projection_requirements(
#     780                 *args, **kwargs)
# --> 781             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     782             key = (projection_class, pkw)
#     783         return self._add_axes_internal(ax, key)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      34         """
#      35         # _axes_class is set in the subplot_class_factory
# ---> 36         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      37         # This will also update the axes position.
#      38         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# ~\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     632
#     633         self._rasterization_zorder = None
# --> 634         self.cla()
#     635
#     636         # funcs used to format x and y - fall back on major formatters
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1201                 pass
#    1202         if self._sharey is not None:
# -> 1203             self.sharey(self._sharey)
#    1204         else:
#    1205             self.yaxis._set_scale('linear')
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in sharey(self, other)
#    1162         if self._sharey is not None and other is not self._sharey:
#    1163             raise ValueError("y-axis is already shared")
# -> 1164         self._shared_y_axes.join(self, other)
#    1165         self._sharey = other
#    1166         self.yaxis.major = other.yaxis.major  # Ticker instances holding
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in join(self, a, *args)
#     880                     mapping[elem] = set_a
#     881
# --> 882         self.clean()
#     883
#     884     def joined(self, a, b):
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in clean(self)
#     859         """Clean dead weak references from the dictionary."""
#     860         mapping = self._mapping
# --> 861         to_drop = [key for key in mapping if key() is None]
#     862         for key in to_drop:
#     863             val = mapping.pop(key)
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in <listcomp>(.0)
#     859         """Clean dead weak references from the dictionary."""
#     860         mapping = self._mapping
# --> 861         to_drop = [key for key in mapping if key() is None]
#     862         for key in to_drop:
#     863             val = mapping.pop(key)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001C0F9A7F0D0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\Anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2219                 # CL works.  "tight" also needs a draw to get the right
#    2220                 # locations:
# -> 2221                 renderer = _get_renderer(
#    2222                     self.figure,
#    2223                     functools.partial(
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in _get_renderer(figure, print_method)
#    1574                 figure.canvas._get_output_canvas(None, fmt), f"print_{fmt}")
#    1575         try:
# -> 1576             print_method(io.BytesIO())
#    1577         except Done as exc:
#    1578             renderer, = figure._cachedRenderer, = exc.args
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     399     def draw(self):
#     400         # docstring inherited
# --> 401         self.renderer = self.get_renderer(cleared=True)
#     402         # Acquire a lock on the shared font cache.
#     403         with RendererAgg.lock, \
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     415                           and getattr(self, "_lastKey", None) == key)
#     416         if not reuse_renderer:
# --> 417             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     418             self._lastKey = key
#     419         elif cleared:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      89         self.width = width
#      90         self.height = height
# ---> 91         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      92         self._filter_renderers = []
#      93
#
# KeyboardInterrupt:
